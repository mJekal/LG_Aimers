# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import matplotlib as mpl
# %matplotlib inline
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 200)

# %%
import os, sys
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
default_dir = "/content/gdrive/My Drive"
df_train = pd.read_csv(os.path.join(default_dir,"train.csv")) # 학습용 데이터
df_test = pd.read_csv(os.path.join(default_dir,"submission.csv")) # 테스트 데이터(제출파일의 데이터)

# %% [markdown]
# # ver_win_ratio_per_bu
# - 결측치 비율 : 0.741918
# - 'business_area', 'business_unit'와 밀접하게 관련
# - 'business_area'와 'business_unit'이 같으면 같은 값
# - 'business_area'가 결측치 이면 'ver_win_ratio_per_bu'도 결측치 이다.
# - 'business_area'와 'business_unit' 둘 다 존재하는데 NaN값도 있다.
# - 칼럼 삭제?

# %%
df_train['ver_win_ratio_per_bu'].isnull().sum() / df_train.shape[0]
# Out:
# 0.7419180761901549

# %%
df_train['ver_win_ratio_per_bu'].value_counts()
# Out:
# 0.064566    2460
# 0.049840    2028
# 0.020121    1365
# 0.048630    1356
# 0.026846    1278
# 0.064070    1075
# 0.071345     984
# 0.011583     788
# 0.022634     713
# 0.060924     540
# 0.079412     421
# 0.036913     403
# 0.035484     385
# 0.031579     271
# 0.053571     216
# 0.051471     210
# 0.028777     200
# 0.022727     173
# 0.128571     156
# 0.131148     148
# 0.227273      62
# 0.285714      43
# 0.034483      29
# Name: ver_win_ratio_per_bu, dtype: int64

# %%
selected_columns_df = df_train[['business_area', 'business_unit', 'ver_win_ratio_per_bu']]
selected_columns_df
# Out:
#             business_area business_unit  ver_win_ratio_per_bu
# 0      corporate / office            AS              0.026846
# 1      corporate / office            AS              0.026846
# 2      corporate / office            AS              0.026846
# 3      corporate / office            AS              0.026846
# 4      corporate / office            AS              0.026846
# ...                   ...           ...                   ...
# 59294     public facility            AS              0.028777
# 59295     public facility            AS              0.028777
# 59296     public facility            AS              0.028777
# 59297     public facility            AS              0.028777
# 59298     public facility      Solution                   NaN
#
# [59299 rows x 3 columns]

# %%
selected_columns_df = df_train[['business_area', 'business_unit', 'ver_win_ratio_per_bu','is_converted']]
selected_columns_df
# Out:
#             business_area business_unit  ver_win_ratio_per_bu  is_converted
# 0      corporate / office            AS              0.026846          True
# 1      corporate / office            AS              0.026846          True
# 2      corporate / office            AS              0.026846          True
# 3      corporate / office            AS              0.026846          True
# 4      corporate / office            AS              0.026846          True
# ...                   ...           ...                   ...           ...
# 59294     public facility            AS              0.028777         False
# 59295     public facility            AS              0.028777         False
# 59296     public facility            AS              0.028777         False
# 59297     public facility            AS              0.028777         False
# 59298     public facility      Solution                   NaN         False
#
# [59299 rows x 4 columns]
