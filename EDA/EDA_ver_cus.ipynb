# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import matplotlib as mpl
# %matplotlib inline
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
import os, sys
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
default_dir = "/content/gdrive/My Drive"
df_train = pd.read_csv(os.path.join(default_dir,"train.csv")) # 학습용 데이터
df_test = pd.read_csv(os.path.join(default_dir,"submission.csv")) # 테스트 데이터(제출파일의 데이터)

# %% [markdown]
# # ver_cus
# - 결측치 없음
# - ver_cus와 business_area, customer_type과 밀접한 관련
# - ver_cus가 1인데 business_area나 customer_type이 결측치인 경우는 없다
# - ver_cus가 1인 경우 :
#   - business_area type :
#   - hotel & accommodation
#   -	retail
#   - education
#   - corporate / office

# %%
df_train['ver_cus'].value_counts()
# Out:
# 0    56832
# 1     2467
# Name: ver_cus, dtype: int64

# %%
selected_columns_df = df_train[['business_area', 'customer_type', 'ver_cus']]
selected_columns_df
# Out:
#             business_area          customer_type  ver_cus
# 0      corporate / office           End-Customer        1
# 1      corporate / office           End-Customer        1
# 2      corporate / office           End-Customer        1
# 3      corporate / office           End-Customer        1
# 4      corporate / office  Specifier/ Influencer        0
# ...                   ...                    ...      ...
# 59294     public facility           End Customer        0
# 59295     public facility  Specifier/ Influencer        0
# 59296     public facility  Specifier/ Influencer        0
# 59297     public facility                    NaN        0
# 59298     public facility                    NaN        0
#
# [59299 rows x 3 columns]

# %%
selected_columns_df = df_train[['business_area', 'customer_type', 'ver_cus']]
selected_columns_df[selected_columns_df['customer_type'] == 'End-Customer']
# Out:
#             business_area customer_type  ver_cus
# 0      corporate / office  End-Customer        1
# 1      corporate / office  End-Customer        1
# 2      corporate / office  End-Customer        1
# 3      corporate / office  End-Customer        1
# 5      corporate / office  End-Customer        1
# ...                   ...           ...      ...
# 59272     public facility  End-Customer        0
# 59277     public facility  End-Customer        0
# 59279     public facility  End-Customer        0
# 59284     public facility  End-Customer        0
# 59285     public facility  End-Customer        0
#
# [6647 rows x 3 columns]

# %%
selected_columns_df = df_train[['business_area', 'customer_type', 'ver_cus']]
selected_columns_df[selected_columns_df['ver_cus'] == 0]
# Out:
#             business_area          customer_type  ver_cus
# 4      corporate / office  Specifier/ Influencer        0
# 8      corporate / office  Specifier/ Influencer        0
# 12     corporate / office        Service Partner        0
# 15     corporate / office  Specifier/ Influencer        0
# 16     corporate / office  Specifier/ Influencer        0
# ...                   ...                    ...      ...
# 59294     public facility           End Customer        0
# 59295     public facility  Specifier/ Influencer        0
# 59296     public facility  Specifier/ Influencer        0
# 59297     public facility                    NaN        0
# 59298     public facility                    NaN        0
#
# [56832 rows x 3 columns]

# %%
selected_columns_df = df_train[['business_area', 'customer_type', 'ver_cus']]
selected_columns_df[selected_columns_df['customer_type'] == 'End Customer']
# Out:
#             business_area customer_type  ver_cus
# 318    corporate / office  End Customer        1
# 321    corporate / office  End Customer        1
# 322    corporate / office  End Customer        1
# 323    corporate / office  End Customer        1
# 327    corporate / office  End Customer        1
# ...                   ...           ...      ...
# 59280     public facility  End Customer        0
# 59281     public facility  End Customer        0
# 59286     public facility  End Customer        0
# 59293     public facility  End Customer        0
# 59294     public facility  End Customer        0
#
# [3996 rows x 3 columns]

# %%
df_train['customer_type'] = df_train['customer_type'].str.lower().str.replace(" ", "")

# %%
customer_type_mapping = {
  'End Customer': ['endcustomer','end-user','end-customer','constructioncompany', 'owner/developer', 'medical/healthcarefacility', 'government/publicsector', 'corporate', 'education', 'retail', 'fitness'],
 'Channel Partner' : ['agent','channelpartner', 'distributor','reseller', 'nsp(usonly)', 'nationalreseller', 'regionalreseller', 'si(systemintegrator)', 'proav/avconsultant', 'var(3po)'],
 'Specifier/ Influencer': ['specifier/influencer','architect', 'consultant', 'contractor', 'technical/designfirm', 'regionbuilder', 'installer',  'ad&contentsprovider', 'appliedrep'],
 'Solution Eco-Partner': ['solutioneco-partner','cms/webos/isv', 'mount/metalfabrication','meetingsolution',  'control/processor', 'externalcompute'],
 'Service Partner': ['servicepartner','authorizedservicecenter', 'authorizedservicedealer'],
 }

def map_customer_type_category(value):
    for customer_type, values in customer_type_mapping.items():
        if value in values:
            return customer_type
    return value  # 매핑되지 않은 경우 원래 값을 반환

df_train['customer_type'] = df_train['customer_type'].apply(map_customer_type_category)

# %%
selected_columns_df = df_train[['business_area', 'customer_type', 'ver_cus']]
selected_columns_df[selected_columns_df['ver_cus'] == 1]
# Out:
#                business_area customer_type  ver_cus
# 0         corporate / office  End Customer        1
# 1         corporate / office  End Customer        1
# 2         corporate / office  End Customer        1
# 3         corporate / office  End Customer        1
# 5         corporate / office  End Customer        1
# ...                      ...           ...      ...
# 58168  hotel & accommodation  End Customer        1
# 58169  hotel & accommodation  End Customer        1
# 58170  hotel & accommodation  End Customer        1
# 58171  hotel & accommodation  End Customer        1
# 58172  hotel & accommodation  End Customer        1
#
# [2467 rows x 3 columns]
