# %% [markdown]
# # 영업 성공 여부 분류 경진대회

# %% [markdown]
# ## 1. 데이터 확인

# %% [markdown]
# ### 필수 라이브러리

# %%
# !pip install seaborn
# !pip install miceforest
# !pip install fancyimpute
# !pip install missingno
# !pip install hyperopt
# !pip install bayesian-optimization
# !pip install catboost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import matplotlib as mpl

# %matplotlib inline
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from catboost import CatBoostClassifier
from hyperopt import hp, tpe, Trials, fmin
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from hyperopt import hp
from hyperopt import STATUS_OK
from hyperopt import fmin, tpe, Trials
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from fancyimpute import IterativeImputer
from sklearn.experimental import enable_iterative_imputer
import miceforest as mf
from sklearn.model_selection import KFold
from sklearn.preprocessing import OneHotEncoder
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import VotingClassifier
from lightgbm import plot_importance
from sklearn.ensemble import GradientBoostingClassifier
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ### 데이터 셋 읽어오기

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
df_test.head() # 학습용 데이터 살펴보기
# Out:
#       id  bant_submit                                   customer_country  \
# 0  19844         0.00                                        /  / Brazil
# 1   9738         0.25  400 N State Of Franklin Rd  Cloud IT / Johnson...
# 2   8491         1.00                                         /  / U.A.E
# 3  19895         0.50                         / Madison  / United States
# 4  10465         1.00                               / Sao Paulo / Brazil
#
#   business_unit  com_reg_ver_win_rate  customer_idx          customer_type  \
# 0            ID              0.073248         47466           End Customer
# 1            IT                   NaN          5405           End Customer
# 2            ID                   NaN         13597  Specifier/ Influencer
# 3            ID              0.118644         17204                    NaN
# 4            ID              0.074949          2329           End Customer
#
#    enterprise  historical_existing_cnt  id_strategic_ver  it_strategic_ver  \
# 0  Enterprise                     53.0               NaN               NaN
# 1         SMB                      NaN               NaN               NaN
# 2         SMB                      NaN               NaN               NaN
# 3  Enterprise                      NaN               NaN               NaN
# 4  Enterprise                      2.0               1.0               NaN
#
#    idit_strategic_ver            customer_job  lead_desc_length  \
# 0                 NaN              consulting                 3
# 1                 NaN                     NaN                23
# 2                 NaN  information technology               138
# 3                 NaN                   sales                 3
# 4                 1.0             engineering               107
#
#                          inquiry_type product_category  \
# 0                                 NaN              NaN
# 1  Quotation or Purchase Consultation              NaN
# 2  Quotation or Purchase Consultation      hospital tv
# 3  Quotation or Purchase Consultation              NaN
# 4  Quotation or Purchase Consultation      led signage
#
#                  product_subcategory product_modelname  \
# 0                                NaN               NaN
# 1                                NaN               NaN
# 2                      UT662M Series    50UT662M (MEA)
# 3  Digital Signage or Commercial TVs               NaN
# 4                        LG LED Bloc           LSAA012
#
#                                   customer_country.1 customer_position  \
# 0                                        /  / Brazil              none
# 1  400 N State Of Franklin Rd  Cloud IT / Johnson...              none
# 2                                         /  / U.A.E           manager
# 3                         / Madison  / United States              none
# 4                               / Sao Paulo / Brazil            others
#
#   response_corporate   expected_timeline  ver_cus  ver_pro  ver_win_rate_x  \
# 0              LGESP                 NaN        1        0        0.001183
# 1              LGEUS                 NaN        0        0        0.000013
# 2              LGEGF  less than 3 months        0        0        0.000060
# 3              LGEUS    more than a year        0        0        0.001183
# 4              LGESP  less than 3 months        1        1        0.003079
#
#    ver_win_ratio_per_bu           business_area     business_subarea  \
# 0              0.049840                  retail  Electronics & Telco
# 1                   NaN          transportation               Others
# 2              0.131148  hospital & health care     General Hospital
# 3              0.049840                  retail                  NaN
# 4              0.064566      corporate / office          Engineering
#
#    lead_owner  is_converted
# 0         278         False
# 1         437          True
# 2         874         False
# 3         194         False
# 4         167         False

# %%
df_train['ver_test'] = df_train['ver_win_ratio_per_bu'] / df_train['ver_win_rate_x']
df_test['ver_test'] = df_test['ver_win_ratio_per_bu'] / df_test['ver_win_rate_x']

# %%
df_train['product_category'] = df_train['product_category'].str.lower().str.replace(" ", "")
df_test['product_category'] = df_test['product_category'].str.lower().str.replace(" ", "")

# %%
product_mapping = { 'HVAC/ESS': ['control', 'ventilation', 'vrf', 'multi-split', 'arcondicionadoresidencial','single-split', 'chiler','chiller', 'heating','rac','tetooucasseteinverter','multiinverter'],
                     'Commercial Display': ['monitorsignage,monior/monitortv','monitorsignage,monior/monitortv,vacuumcleaner,...	','tvsignage','monitorsignage,commercialtv,monior/monitortv','interactivedigitalboard','digitalsignage','signagecaresolutions','smarttvsignage','uhdsignage','oledsignage', 'ledsignage', 'videowallsignage', 'videowall','interactivesignage', 'highbrightnesssignage','highbrightness', 'specialsignage', 'standardsignage', 'hoteltv', 'hospitaltv', 'signagecaresolution', 'lgone:quickseries','accessories', 'webos', 'one:quickseries', 'pro:centric'],
                      'IT PRODUCTS': ['monitor', 'laptop', 'projector','pc', 'clouddevice', 'medicaldisplay'],
                      'Commerical Laundry': ['titan(largecapacity)', 'giant(standardcapacity)'],
                      'Compressor & Motor': ['reciprocatingcompressor', 'rotarycompressor', 'scrollcompressor', 'motor'],
                      'ADVANCED MATERIALS': ['antimicrobial', 'porcelainenamel', 'specialtyglass'] ,
                      'Robot': ['lgcloiuv-cbot', 'lgcloiservebot(shelftype)', 'lgcloiservebot(drawertype)', 'lgcloiguidebot'],
                      'Others':['etc.','others','other','softwaresolution']
                    }

def map_product_category(value):
    for product, values in product_mapping.items():
        if value in values:
            return product
    return value  # 매핑되지 않은 경우 원래 값을 반환

df_train['Product'] = df_train['product_category'].apply(map_product_category)
df_test['Product'] = df_test['product_category'].apply(map_product_category)

# %% [markdown]
# ## 2. 데이터 전처리

# %%
df_train['customer_type'] = df_train['customer_type'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_test['customer_type'] = df_test['customer_type'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_train['customer_job'] = df_train['customer_job'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_test['customer_job'] = df_test['customer_job'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_train['inquiry_type'] = df_train['inquiry_type'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_test['inquiry_type'] = df_test['inquiry_type'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_train['customer_position'] = df_train['customer_position'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_test['customer_position'] = df_test['customer_position'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_train['expected_timeline'] = df_train['expected_timeline'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)
df_test['expected_timeline'] = df_test['expected_timeline'].str.lower().replace(r'[^a-zA-Z0-9]', '', regex=True)

# %%
df_train['ver_country'] = df_train['com_reg_ver_win_rate'] / df_train['ver_win_ratio_per_bu']
df_test['ver_country'] = df_test['com_reg_ver_win_rate'] / df_test['ver_win_ratio_per_bu']

# %%
cond1 = (
    (df_train['business_unit'] == 'ID') &
    ((df_train['business_area'] == 'corporate / office') | (df_train['business_area'] == 'hotel & accommodation'))
    & df_train['id_strategic_ver'].isna())

cond2 = (
    (df_test['business_unit'] == 'ID') &
    ((df_test['business_area'] == 'corporate / office') | (df_test['business_area'] == 'hotel & accommodation'))
    & df_test['id_strategic_ver'].isna())
cond3 = (
    (df_train['business_unit'] == 'IT') &
    ((df_train['business_area'] == 'corporate / office') | (df_train['business_area'] == 'hotel & accommodation'))
    & df_train['it_strategic_ver'].isna())

cond4 = (
    (df_test['business_unit'] == 'IT') &
    ((df_test['business_area'] == 'corporate / office') | (df_test['business_area'] == 'hotel & accommodation'))
    & df_test['it_strategic_ver'].isna())

# %%
df_train.loc[cond1, 'id_strategic_ver'] = 1
df_train['id_strategic_ver'] = df_train['id_strategic_ver'].fillna(0)
df_test.loc[cond2, 'id_strategic_ver'] = 1
df_test['id_strategic_ver'] = df_test['id_strategic_ver'].fillna(0)
df_train.loc[cond3, 'it_strategic_ver'] = 1
df_train['it_strategic_ver'] = df_train['it_strategic_ver'].fillna(0)
df_test.loc[cond4, 'it_strategic_ver'] = 1
df_test['it_strategic_ver'] = df_test['it_strategic_ver'].fillna(0)
df_train['idit_strategic_ver'] = df_train.apply(lambda row: 1 if row['id_strategic_ver'] == 1 or row['it_strategic_ver'] == 1 else 0, axis=1)
df_test['idit_strategic_ver'] = df_test.apply(lambda row: 1 if row['id_strategic_ver'] == 1 or row['it_strategic_ver'] == 1 else 0, axis=1)

# %%
numeric_columns = df_train.select_dtypes(include='number')

columns_without_missing_values = numeric_columns.columns[numeric_columns.isnull().sum() == 0]

columns_to_exclude = ['id_strategic_ver', 'it_strategic_ver','idit_strategic_ver']
columns_to_exclude.extend(columns_without_missing_values)

columns_to_impute = numeric_columns.drop(columns=columns_to_exclude, errors='ignore')

imputer = IterativeImputer()

df_train_imputed = pd.DataFrame(imputer.fit_transform(columns_to_impute), columns=columns_to_impute.columns)

replacement_values = df_train_imputed.mean()
print("각 열의 대체값:")
print(dict(zip(columns_to_impute.columns, replacement_values)))
# Out:
# 각 열의 대체값:
# {'com_reg_ver_win_rate': 0.09165432923188417, 'historical_existing_cnt': 18.403146499021506, 'ver_win_rate_x': 0.0011355375848576702, 'ver_win_ratio_per_bu': 0.055515326376435206, 'ver_test': 2634.475440829076, 'ver_country': 1.6052930268839807}
# /home/elicer/.local/lib/python3.10/site-packages/sklearn/impute/_iterative.py:785: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
df_train[columns_to_impute.columns] = df_train[columns_to_impute.columns].fillna(replacement_values)
df_test[columns_to_impute.columns] = df_test[columns_to_impute.columns].fillna(replacement_values)

# %%
df_train = df_train.drop(['ver_pro','ver_win_ratio_per_bu','id_strategic_ver','it_strategic_ver','idit_strategic_ver','product_category','com_reg_ver_win_rate',"business_area","business_subarea","customer_country","product_subcategory", "product_modelname","customer_country.1"], axis=1)
df_test = df_test.drop(['ver_pro','ver_win_ratio_per_bu','ver_win_ratio_per_bu','id_strategic_ver','it_strategic_ver','idit_strategic_ver','product_category','com_reg_ver_win_rate',"business_area","business_subarea","customer_country","product_subcategory", "product_modelname","customer_country.1"], axis=1)

# %% [markdown]
# ### 레이블 인코딩

# %%
# 레이블 인코딩할 칼럼들
label_columns = [
   #"customer_country",
   # "business_subarea",
  #  "business_area",
    "business_unit",
    "customer_type",
   "enterprise",
    "customer_job",
    "inquiry_type",
   # "product_category",
  #  "product_subcategory",
  #  "product_modelname",
   # "customer_country.1",
   "customer_position",
   "response_corporate",
    "expected_timeline",
    "Product"
   #"Continent",
    # "Country"
]


df_all = pd.concat([df_train[label_columns], df_test[label_columns]])

for column in label_columns:
    df_all[column] = pd.factorize(df_all[column])[0]

# %%
for col in label_columns:
    df_train[col] = df_all.iloc[: len(df_train)][col]
    df_test[col] = df_all.iloc[len(df_train) :][col]

# %% [markdown]
# ### 2-2. 학습, 검증 데이터 분리

# %%
x_train, x_val, y_train, y_val = train_test_split(
    df_train.drop("is_converted", axis=1),
    df_train["is_converted"],
    test_size=0.2,
    shuffle=True,
    random_state=400,)

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
bayesian_params = {
    'max_depth': (6, 16), 
    'num_leaves': (24, 64), 
    'min_child_samples': (10, 200), 
    'min_child_weight':(1, 50),
    'subsample':(0.5, 1.0),
    'colsample_bytree': (0.5, 1.0),
    'max_bin':(10, 500),
    'reg_lambda':(0.001, 10),
    'reg_alpha': (0.01, 50) 
}

# %%
def lgb_f1_eval(max_depth, num_leaves, min_child_samples, min_child_weight, subsample, 
                colsample_bytree,max_bin, reg_lambda, reg_alpha):
    params = {
        "n_estimators":500, "learning_rate":0.02,
        'max_depth': int(round(max_depth)), 
        'num_leaves': int(round(num_leaves)), 
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0), 
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin':  max(int(round(max_bin)),10),
        'reg_lambda': max(reg_lambda,0),
        'reg_alpha': max(reg_alpha, 0)
    }
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(x_train, y_train, eval_set=[(x_train, y_train), (x_val, y_val)], eval_metric= 'f1', callbacks = [lgb.early_stopping(stopping_rounds = 100), lgb.log_evaluation(period = 100)],)
    valid_pred = lgb_model.predict(x_val)
    f1 = f1_score(y_val,valid_pred)
    
    return f1

# %%
lgbBO = BayesianOptimization(lgb_f1_eval,bayesian_params , random_state=0)
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.126742	valid_1's binary_logloss: 0.13021
# [200]	training's binary_logloss: 0.10412	valid_1's binary_logloss: 0.109942
# [300]	training's binary_logloss: 0.0955911	valid_1's binary_logloss: 0.102627
# [400]	training's binary_logloss: 0.0911809	valid_1's binary_logloss: 0.0992772
# [500]	training's binary_logloss: 0.0883285	valid_1's binary_logloss: 0.0971006
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0883285	valid_1's binary_logloss: 0.0971006
# | 1         | 0.7216    | 0.7744    | 360.4     | 12.03     | 113.5     | 21.76     | 49.84     | 21.88     | 8.918     | 0.9818    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.122464	valid_1's binary_logloss: 0.126487
# [200]	training's binary_logloss: 0.0980068	valid_1's binary_logloss: 0.105118
# [300]	training's binary_logloss: 0.089042	valid_1's binary_logloss: 0.0977328
# [400]	training's binary_logloss: 0.0840119	valid_1's binary_logloss: 0.093957
# [500]	training's binary_logloss: 0.0805425	valid_1's binary_logloss: 0.0913118
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0805425	valid_1's binary_logloss: 0.0913118
# | 2         | 0.7415    | 0.6917    | 397.9     | 11.29     | 117.9     | 46.35     | 26.84     | 4.366     | 0.2032    | 0.9163    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.116203	valid_1's binary_logloss: 0.12128
# [200]	training's binary_logloss: 0.0922053	valid_1's binary_logloss: 0.100363
# [300]	training's binary_logloss: 0.0822193	valid_1's binary_logloss: 0.092385
# [400]	training's binary_logloss: 0.0767777	valid_1's binary_logloss: 0.0883781
# [500]	training's binary_logloss: 0.072879	valid_1's binary_logloss: 0.0855835
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.072879	valid_1's binary_logloss: 0.0855835
# | 3         | 0.7577    | 0.8891    | 436.3     | 15.79     | 161.8     | 23.61     | 55.22     | 5.923     | 6.4       | 0.5717    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.126227	valid_1's binary_logloss: 0.12874
# [200]	training's binary_logloss: 0.105591	valid_1's binary_logloss: 0.110237
# [300]	training's binary_logloss: 0.0981276	valid_1's binary_logloss: 0.104205
# [400]	training's binary_logloss: 0.0945644	valid_1's binary_logloss: 0.101456
# [500]	training's binary_logloss: 0.0924867	valid_1's binary_logloss: 0.0997812
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0924867	valid_1's binary_logloss: 0.0997812
# | 4         | 0.7207    | 0.9723    | 265.7     | 10.15     | 60.27     | 38.94     | 42.25     | 28.43     | 0.1889    | 0.8088    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.128686	valid_1's binary_logloss: 0.131379
# [200]	training's binary_logloss: 0.108313	valid_1's binary_logloss: 0.113019
# [300]	training's binary_logloss: 0.101276	valid_1's binary_logloss: 0.107019
# [400]	training's binary_logloss: 0.0976954	valid_1's binary_logloss: 0.10414
# [500]	training's binary_logloss: 0.095771	valid_1's binary_logloss: 0.102642
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.095771	valid_1's binary_logloss: 0.102642
# | 5         | 0.7144    | 0.806     | 312.3     | 15.44     | 139.5     | 18.62     | 41.48     | 34.88     | 0.6032    | 0.8334    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.118317	valid_1's binary_logloss: 0.122784
# [200]	training's binary_logloss: 0.0956422	valid_1's binary_logloss: 0.102924
# [300]	training's binary_logloss: 0.0871644	valid_1's binary_logloss: 0.0961392
# [400]	training's binary_logloss: 0.0820378	valid_1's binary_logloss: 0.0921524
# [500]	training's binary_logloss: 0.0785059	valid_1's binary_logloss: 0.0896102
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0785059	valid_1's binary_logloss: 0.0896102
# | 6         | 0.7467    | 0.8155    | 500.0     | 12.35     | 162.3     | 50.0      | 24.0      | 0.01      | 0.8228    | 0.5463    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.120936	valid_1's binary_logloss: 0.124968
# [200]	training's binary_logloss: 0.0981467	valid_1's binary_logloss: 0.105093
# [300]	training's binary_logloss: 0.0891643	valid_1's binary_logloss: 0.0977685
# [400]	training's binary_logloss: 0.084083	valid_1's binary_logloss: 0.0938328
# [500]	training's binary_logloss: 0.0802926	valid_1's binary_logloss: 0.0909499
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0802926	valid_1's binary_logloss: 0.0909499
# | 7         | 0.743     | 0.8348    | 405.6     | 14.78     | 115.7     | 47.33     | 24.63     | 3.461     | 5.163     | 0.7811    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.130087	valid_1's binary_logloss: 0.132548
# [200]	training's binary_logloss: 0.110116	valid_1's binary_logloss: 0.11467
# [300]	training's binary_logloss: 0.10313	valid_1's binary_logloss: 0.108801
# [400]	training's binary_logloss: 0.0997098	valid_1's binary_logloss: 0.105883
# [500]	training's binary_logloss: 0.098211	valid_1's binary_logloss: 0.104634
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.098211	valid_1's binary_logloss: 0.104634
# | 8         | 0.7077    | 0.8815    | 480.3     | 12.12     | 199.1     | 2.291     | 50.15     | 44.13     | 2.983     | 0.5046    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.126232	valid_1's binary_logloss: 0.13014
# [200]	training's binary_logloss: 0.100461	valid_1's binary_logloss: 0.107105
# [300]	training's binary_logloss: 0.0917476	valid_1's binary_logloss: 0.0997804
# [400]	training's binary_logloss: 0.0869602	valid_1's binary_logloss: 0.0958725
# [500]	training's binary_logloss: 0.0840851	valid_1's binary_logloss: 0.0936597
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0840851	valid_1's binary_logloss: 0.0936597
# | 9         | 0.7399    | 0.5       | 454.3     | 7.364     | 134.7     | 50.0      | 64.0      | 0.01      | 0.001     | 0.8202    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.121497	valid_1's binary_logloss: 0.125594
# [200]	training's binary_logloss: 0.0978832	valid_1's binary_logloss: 0.104886
# [300]	training's binary_logloss: 0.0889279	valid_1's binary_logloss: 0.0979883
# [400]	training's binary_logloss: 0.0835134	valid_1's binary_logloss: 0.0938345
# [500]	training's binary_logloss: 0.0795923	valid_1's binary_logloss: 0.0908962
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0795923	valid_1's binary_logloss: 0.0908962
# | 10        | 0.7488    | 1.0       | 428.2     | 16.0      | 171.1     | 44.83     | 26.13     | 0.01      | 10.0      | 0.7282    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.132706	valid_1's binary_logloss: 0.135746
# [200]	training's binary_logloss: 0.106542	valid_1's binary_logloss: 0.112068
# [300]	training's binary_logloss: 0.0964572	valid_1's binary_logloss: 0.103584
# [400]	training's binary_logloss: 0.090887	valid_1's binary_logloss: 0.099098
# [500]	training's binary_logloss: 0.0875563	valid_1's binary_logloss: 0.096436
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0875563	valid_1's binary_logloss: 0.096436
# | 11        | 0.7346    | 0.5017    | 393.7     | 10.71     | 119.0     | 45.57     | 28.2      | 10.95     | 4.662     | 0.9552    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.108742	valid_1's binary_logloss: 0.115332
# [200]	training's binary_logloss: 0.0845989	valid_1's binary_logloss: 0.0946546
# [300]	training's binary_logloss: 0.074348	valid_1's binary_logloss: 0.0873242
# [400]	training's binary_logloss: 0.0677917	valid_1's binary_logloss: 0.0833843
# [500]	training's binary_logloss: 0.0631399	valid_1's binary_logloss: 0.0808239
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0631399	valid_1's binary_logloss: 0.0808239
# | 12        | 0.7842    | 1.0       | 437.0     | 16.0      | 142.3     | 8.545     | 28.16     | 0.01      | 0.001     | 0.5       |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.119823	valid_1's binary_logloss: 0.124495
# [200]	training's binary_logloss: 0.0964248	valid_1's binary_logloss: 0.103647
# [300]	training's binary_logloss: 0.087499	valid_1's binary_logloss: 0.0966374
# [400]	training's binary_logloss: 0.0827884	valid_1's binary_logloss: 0.0930599
# [500]	training's binary_logloss: 0.0797628	valid_1's binary_logloss: 0.0907715
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0797628	valid_1's binary_logloss: 0.0907715
# | 13        | 0.7453    | 0.8227    | 418.8     | 8.331     | 51.9      | 10.05     | 55.87     | 15.55     | 8.403     | 0.9562    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.117389	valid_1's binary_logloss: 0.122116
# [200]	training's binary_logloss: 0.0937827	valid_1's binary_logloss: 0.101413
# [300]	training's binary_logloss: 0.0838222	valid_1's binary_logloss: 0.0933239
# [400]	training's binary_logloss: 0.0780476	valid_1's binary_logloss: 0.0888601
# [500]	training's binary_logloss: 0.0740012	valid_1's binary_logloss: 0.0858105
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0740012	valid_1's binary_logloss: 0.0858105
# | 14        | 0.7629    | 0.8254    | 437.9     | 9.569     | 118.3     | 1.061     | 25.18     | 6.293     | 5.566     | 0.9338    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.124822	valid_1's binary_logloss: 0.128191
# [200]	training's binary_logloss: 0.103812	valid_1's binary_logloss: 0.10949
# [300]	training's binary_logloss: 0.0954493	valid_1's binary_logloss: 0.102748
# [400]	training's binary_logloss: 0.0912674	valid_1's binary_logloss: 0.0995204
# [500]	training's binary_logloss: 0.0888188	valid_1's binary_logloss: 0.0976448
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0888188	valid_1's binary_logloss: 0.0976448
# | 15        | 0.7276    | 0.9303    | 325.1     | 15.91     | 120.2     | 1.1       | 29.0      | 25.81     | 5.161     | 0.5704    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.128056	valid_1's binary_logloss: 0.130579
# [200]	training's binary_logloss: 0.10483	valid_1's binary_logloss: 0.109832
# [300]	training's binary_logloss: 0.0962233	valid_1's binary_logloss: 0.102851
# [400]	training's binary_logloss: 0.0916522	valid_1's binary_logloss: 0.0992227
# [500]	training's binary_logloss: 0.0888609	valid_1's binary_logloss: 0.0969965
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0888609	valid_1's binary_logloss: 0.0969965
# | 16        | 0.7272    | 0.7405    | 120.1     | 12.18     | 53.76     | 42.68     | 47.66     | 10.66     | 1.986     | 0.8184    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.136167	valid_1's binary_logloss: 0.138491
# [200]	training's binary_logloss: 0.111997	valid_1's binary_logloss: 0.11649
# [300]	training's binary_logloss: 0.103143	valid_1's binary_logloss: 0.108877
# [400]	training's binary_logloss: 0.0988265	valid_1's binary_logloss: 0.105361
# [500]	training's binary_logloss: 0.0964357	valid_1's binary_logloss: 0.103468
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0964357	valid_1's binary_logloss: 0.103468
# | 17        | 0.7093    | 0.5286    | 456.4     | 13.47     | 96.72     | 41.56     | 61.51     | 29.92     | 3.57      | 0.8466    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.111887	valid_1's binary_logloss: 0.117212
# [200]	training's binary_logloss: 0.0884303	valid_1's binary_logloss: 0.0964166
# [300]	training's binary_logloss: 0.0780508	valid_1's binary_logloss: 0.0885701
# [400]	training's binary_logloss: 0.0718059	valid_1's binary_logloss: 0.084523
# [500]	training's binary_logloss: 0.0668597	valid_1's binary_logloss: 0.081511
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0668597	valid_1's binary_logloss: 0.081511
# | 18        | 0.7808    | 1.0       | 416.4     | 16.0      | 153.2     | 1.0       | 24.0      | 0.01      | 0.001     | 0.5       |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.130865	valid_1's binary_logloss: 0.133661
# [200]	training's binary_logloss: 0.110117	valid_1's binary_logloss: 0.114965
# [300]	training's binary_logloss: 0.102905	valid_1's binary_logloss: 0.108758
# [400]	training's binary_logloss: 0.0996786	valid_1's binary_logloss: 0.106192
# [500]	training's binary_logloss: 0.0977274	valid_1's binary_logloss: 0.104568
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0977274	valid_1's binary_logloss: 0.104568
# | 19        | 0.7063    | 0.9644    | 330.1     | 10.67     | 22.2      | 30.45     | 42.41     | 41.12     | 7.102     | 0.755     |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.123177	valid_1's binary_logloss: 0.128229
# [200]	training's binary_logloss: 0.0938992	valid_1's binary_logloss: 0.102214
# [300]	training's binary_logloss: 0.0825444	valid_1's binary_logloss: 0.0926497
# [400]	training's binary_logloss: 0.077534	valid_1's binary_logloss: 0.088967
# [500]	training's binary_logloss: 0.0731338	valid_1's binary_logloss: 0.0859649
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0731338	valid_1's binary_logloss: 0.0859649
# | 20        | 0.7577    | 0.5       | 445.7     | 6.0       | 161.1     | 1.0       | 24.0      | 0.01      | 0.001     | 0.5       |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.139317	valid_1's binary_logloss: 0.140832
# [200]	training's binary_logloss: 0.117571	valid_1's binary_logloss: 0.120754
# [300]	training's binary_logloss: 0.109432	valid_1's binary_logloss: 0.113478
# [400]	training's binary_logloss: 0.105506	valid_1's binary_logloss: 0.110163
# [500]	training's binary_logloss: 0.103386	valid_1's binary_logloss: 0.108451
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.103386	valid_1's binary_logloss: 0.108451
# | 21        | 0.6985    | 0.6587    | 250.5     | 9.987     | 100.8     | 48.75     | 36.58     | 41.15     | 9.618     | 0.6229    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.125373	valid_1's binary_logloss: 0.128556
# [200]	training's binary_logloss: 0.104952	valid_1's binary_logloss: 0.110412
# [300]	training's binary_logloss: 0.0971363	valid_1's binary_logloss: 0.103853
# [400]	training's binary_logloss: 0.0934878	valid_1's binary_logloss: 0.101018
# [500]	training's binary_logloss: 0.0920064	valid_1's binary_logloss: 0.099826
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0920064	valid_1's binary_logloss: 0.099826
# | 22        | 0.7196    | 0.9983    | 254.0     | 15.65     | 172.3     | 4.75      | 36.0      | 34.22     | 8.13      | 0.8197    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.13338	valid_1's binary_logloss: 0.135375
# [200]	training's binary_logloss: 0.113533	valid_1's binary_logloss: 0.117229
# [300]	training's binary_logloss: 0.106258	valid_1's binary_logloss: 0.111127
# [400]	training's binary_logloss: 0.102781	valid_1's binary_logloss: 0.108256
# [500]	training's binary_logloss: 0.101084	valid_1's binary_logloss: 0.10686
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.101084	valid_1's binary_logloss: 0.10686
# | 23        | 0.6995    | 0.9707    | 151.7     | 13.38     | 46.18     | 37.89     | 38.31     | 47.9      | 5.181     | 0.5227    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.115908	valid_1's binary_logloss: 0.121857
# [200]	training's binary_logloss: 0.0922735	valid_1's binary_logloss: 0.101382
# [300]	training's binary_logloss: 0.0836841	valid_1's binary_logloss: 0.094694
# [400]	training's binary_logloss: 0.07894	valid_1's binary_logloss: 0.0912038
# [500]	training's binary_logloss: 0.0761629	valid_1's binary_logloss: 0.0892226
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0761629	valid_1's binary_logloss: 0.0892226
# | 24        | 0.7466    | 0.9325    | 418.9     | 14.86     | 48.83     | 2.107     | 50.58     | 16.51     | 7.473     | 0.5513    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.113896	valid_1's binary_logloss: 0.119351
# [200]	training's binary_logloss: 0.0904926	valid_1's binary_logloss: 0.0990422
# [300]	training's binary_logloss: 0.0809104	valid_1's binary_logloss: 0.0918779
# [400]	training's binary_logloss: 0.0759163	valid_1's binary_logloss: 0.0882927
# [500]	training's binary_logloss: 0.072598	valid_1's binary_logloss: 0.0860685
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.072598	valid_1's binary_logloss: 0.0860685
# | 25        | 0.7577    | 0.9331    | 410.7     | 15.16     | 140.3     | 4.428     | 43.17     | 11.94     | 2.303     | 0.8583    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.144367	valid_1's binary_logloss: 0.148579
# [200]	training's binary_logloss: 0.124005	valid_1's binary_logloss: 0.131911
# [300]	training's binary_logloss: 0.116507	valid_1's binary_logloss: 0.126065
# [400]	training's binary_logloss: 0.112287	valid_1's binary_logloss: 0.123299
# [500]	training's binary_logloss: 0.109354	valid_1's binary_logloss: 0.121541
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.109354	valid_1's binary_logloss: 0.121541
# | 26        | 0.6563    | 0.8927    | 10.05     | 7.446     | 193.8     | 29.82     | 58.68     | 0.3353    | 0.6803    | 0.8613    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.107356	valid_1's binary_logloss: 0.114534
# [200]	training's binary_logloss: 0.0832022	valid_1's binary_logloss: 0.0930911
# [300]	training's binary_logloss: 0.0729834	valid_1's binary_logloss: 0.0856507
# [400]	training's binary_logloss: 0.0664897	valid_1's binary_logloss: 0.0815089
# [500]	training's binary_logloss: 0.0617796	valid_1's binary_logloss: 0.0790743
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0617796	valid_1's binary_logloss: 0.0790743
# | 27        | 0.7885    | 1.0       | 500.0     | 16.0      | 10.0      | 1.0       | 24.0      | 0.01      | 0.001     | 1.0       |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.104302	valid_1's binary_logloss: 0.113283
# [200]	training's binary_logloss: 0.0802523	valid_1's binary_logloss: 0.0936255
# [300]	training's binary_logloss: 0.071063	valid_1's binary_logloss: 0.0868415
# [400]	training's binary_logloss: 0.0652531	valid_1's binary_logloss: 0.08298
# [500]	training's binary_logloss: 0.061069	valid_1's binary_logloss: 0.080545
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.061069	valid_1's binary_logloss: 0.080545
# | 28        | 0.7857    | 1.0       | 500.0     | 6.0       | 10.0      | 1.0       | 64.0      | 0.01      | 0.001     | 0.5       |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.119456	valid_1's binary_logloss: 0.123573
# [200]	training's binary_logloss: 0.100376	valid_1's binary_logloss: 0.107042
# [300]	training's binary_logloss: 0.0932835	valid_1's binary_logloss: 0.101183
# [400]	training's binary_logloss: 0.0887429	valid_1's binary_logloss: 0.0975908
# [500]	training's binary_logloss: 0.0858594	valid_1's binary_logloss: 0.0953347
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.0858594	valid_1's binary_logloss: 0.0953347
# | 29        | 0.7334    | 0.8076    | 500.0     | 6.0       | 10.0      | 50.0      | 31.91     | 0.01      | 0.001     | 0.5       |
# Training until validation scores don't improve for 100 rounds
# [100]	training's binary_logloss: 0.128712	valid_1's binary_logloss: 0.132481
# [200]	training's binary_logloss: 0.109118	valid_1's binary_logloss: 0.114944
# [300]	training's binary_logloss: 0.102398	valid_1's binary_logloss: 0.109267
# [400]	training's binary_logloss: 0.0990229	valid_1's binary_logloss: 0.106498
# [500]	training's binary_logloss: 0.0982417	valid_1's binary_logloss: 0.105816
# Did not meet early stopping. Best iteration is:
# [451]	training's binary_logloss: 0.0982417	valid_1's binary_logloss: 0.105816
# | 30        | 0.7087    | 0.9006    | 491.4     | 13.14     | 15.1      | 1.644     | 25.93     | 47.93     | 0.08129   | 0.518     |
# =====================================================================================================================================

# %%
target_list = []
for result in lgbBO.res:
    target = result['target']
    target_list.append(target)
print(target_list)
# 가장 큰 target 값을 가지는 순번(index)를 추출
print('maximum target index:', np.argmax(np.array(target_list)))
# Out:
# [0.7215836526181353, 0.7415307402760352, 0.7576875768757687, 0.7206632653061225, 0.7143786597267403, 0.7467330429371499, 0.7429643527204502, 0.7077326343381389, 0.73989898989899, 0.748768472906404, 0.7346153846153847, 0.7841726618705037, 0.7452711223203026, 0.7628992628992629, 0.7276166456494325, 0.7271581600504096, 0.7093403004572175, 0.7807807807807808, 0.7062706270627063, 0.7576706324358171, 0.6984957488554612, 0.7196382428940568, 0.6995336442371751, 0.746583850931677, 0.7576875768757687, 0.6563275434243176, 0.7885304659498208, 0.7856709168184577, 0.7334183673469388, 0.7087126137841353]
# maximum target index: 26

# %%
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.7885304659498208, 'params': {'colsample_bytree': 1.0, 'max_bin': 500.0, 'max_depth': 16.0, 'min_child_samples': 10.0, 'min_child_weight': 1.0, 'num_leaves': 24.0, 'reg_alpha': 0.01, 'reg_lambda': 0.001, 'subsample': 1.0}}

# %%
def train_apps_all(df_train):
    ftr_app = df_train.drop("is_converted", axis=1)
    target_app = df_train["is_converted"]
    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.2, shuffle=True, random_state=400)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=1000,
                learning_rate=0.02,
                max_depth = 16,
                num_leaves=64,
                colsample_bytree=1,
                subsample=0.716,
                max_bin=474,
                reg_alpha=0.01,
                reg_lambda=0.001,
                min_child_weight=1,
                min_child_samples=143,
                silent=-1,
                verbose=-1,
                )


    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'f1', callbacks = [lgb.early_stopping(stopping_rounds = 100), lgb.log_evaluation(period = 100)])
    
    return clf

# %%
clf = train_apps_all(df_train)
# Out:
# train shape: (47439, 18) valid shape: (11860, 18)
# [LightGBM] [Warning] num_threads is set with nthread=4, will be overridden by n_jobs=-1. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# /home/elicer/.local/lib/python3.10/site-packages/lightgbm/sklearn.py:598: UserWarning: 'silent' argument is deprecated and will be removed in a future release of LightGBM. Pass 'verbose' parameter via keyword arguments instead.
#   _log_warning("'silent' argument is deprecated and will be removed in a future release of LightGBM. "
# [100]	training's binary_logloss: 0.0966901	valid_1's binary_logloss: 0.106591
# [200]	training's binary_logloss: 0.069321	valid_1's binary_logloss: 0.0852778
# [300]	training's binary_logloss: 0.0580626	valid_1's binary_logloss: 0.0783134
# [400]	training's binary_logloss: 0.0501786	valid_1's binary_logloss: 0.0746303
# [500]	training's binary_logloss: 0.044378	valid_1's binary_logloss: 0.0722741
# [600]	training's binary_logloss: 0.0392159	valid_1's binary_logloss: 0.0703214
# [700]	training's binary_logloss: 0.0348559	valid_1's binary_logloss: 0.0691024
# [800]	training's binary_logloss: 0.0310375	valid_1's binary_logloss: 0.0677509
# [900]	training's binary_logloss: 0.027855	valid_1's binary_logloss: 0.0667479
# [1000]	training's binary_logloss: 0.0251256	valid_1's binary_logloss: 0.0661085
# Did not meet early stopping. Best iteration is:
# [1000]	training's binary_logloss: 0.0251256	valid_1's binary_logloss: 0.0661085

# %% [markdown]
# ### 모델 성능 보기

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
pred = clf.predict(x_val)
get_clf_eval(y_val, pred)
# Out:
# 오차행렬:
#  [[  731   216]
#  [   82 10831]]
#
# 정확도: 0.9749
# 정밀도: 0.8991
# 재현율: 0.7719
# F1: 0.8307

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %%
# 예측에 필요한 데이터 분리
x_test = df_test.drop(["is_converted", "id"], axis=1)

# %%
test_pred = clf.predict(x_test)
sum(test_pred) # True로 예측된 개수
# Out:
# 677

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = test_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
